# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriellevsx/gabriellevsx.github.io/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %% [markdown]
# # Loading the packages and libraries

# %%
# !pip install https://github.com/pyannote/pyannote-audio/archive/develop.zip

# %%
# !pip install -q speechbrain
# Out:
#      |████████████████████████████████| 408 kB 8.4 MB/s
#      |████████████████████████████████| 1.2 MB 48.0 MB/s
#      |████████████████████████████████| 67 kB 4.7 MB/s
#      |████████████████████████████████| 109 kB 70.8 MB/s
#      |████████████████████████████████| 596 kB 17.6 MB/s
#      |████████████████████████████████| 546 kB 64.2 MB/s

# %%
from pyannote.audio import Audio 
from IPython.display import Audio as IPythonAudio
from pyannote.core import Segment, notebook
import google.colab
from pyannote.audio import Pipeline

# %% [markdown]
# # Importing the audio file

# %%
own_file, _ = google.colab.files.upload().popitem()
OWN_FILE = {'audio': own_file}
notebook.reset()

waveform, sample_rate = Audio()(OWN_FILE)
IPythonAudio(data=waveform.squeeze(), rate=sample_rate, autoplay=True)
# Out:
#      <input type="file" id="files-ebd137cc-3f9c-4ea9-99d8-752f36c1e685" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ebd137cc-3f9c-4ea9-99d8-752f36c1e685">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving M_0048_11y6m_2.wav to M_0048_11y6m_2.wav

# %% [markdown]
# # Performing the diarization

# %%
#loading the pipeline
pipeline = Pipeline.from_pretrained('pyannote/speaker-diarization')
#performing the diarization
diarization = pipeline(OWN_FILE)
# Out:
# Downloading:   0%|          | 0.00/489 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.7M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.98k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.53M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/129k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-110cebfb9280> in <module>()
#       1 pipeline = Pipeline.from_pretrained('pyannote/speaker-diarization')
# ----> 2 diarization = pipeline(OWN_FILE)
#
# /usr/local/lib/python3.7/dist-packages/pyannote/audio/core/pipeline.py in __call__(self, file, **kwargs)
#     208             file = ProtocolFile(file, lazy=self.preprocessors)
#     209
# ...

# %%
# visualization
diarization

# %%
from pyannote.core import Annotation

# %%
assert isinstance(diarization, Annotation)
